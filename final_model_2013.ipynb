# %% [markdown]
# ## PREDICTING PROJECTS LESS-LIKELY TO BE FUNDED IN 2013

# %%
import pandas as pd

df = pd.read_csv("finalml_file.csv")

# %%
#Checking the number of rows and features
df.shape
# Out:
# (524949, 35)

# %%
df.head().T
# Out:
#                                                                                    0  \
# Unnamed: 0                                                                         0
# projectid                                           ffffac55ee02a49d1abc87ba6fc61135
# donor_city                                                            Peachtree City
# donor_state                                                                       GA
# donation_to_project                                                             42.5
# donation_optional_support                                                        7.5
# donation_total                                                                  50.0
# donation_message                   I gave to this project because I support the e...
# teacher_acctid                                      947066d0af47e0566f334566553dd6a6
# title                                                      Recording Rockin' Readers
# short_description                  Can you imagine having to translate everything...
# need_statement                                        My students need a camcorder.
# essay                              Can you imagine having to translate everything...
# is_exciting                                                                        f
# at_least_1_teacher_referred_donor                                                  f
# fully_funded                                                                       t
# at_least_1_green_donation                                                          t
# great_chat                                                                         f
# school_city                                                                Jonesboro
# school_state                                                                      GA
# school_zip                                                                   30236.0
# schoolid                                            103ed937d8d84fdffe8b87a4811f00bf
# school_charter                                                                     f
# teacher_teach_for_america                                                          f
# primary_focus_subject                                                  Special Needs
# resource_type                                                             Technology
# poverty_level                                                        highest poverty
# grade_level                                                            Grades PreK-2
# students_reached                                                                 8.0
# date_posted                                                               2011-06-11
# vendorid                                                                        82.0
# project_resource_type                                                     Technology
# item_number                                                               BB11216668
# item_unit_price                                                                148.0
# item_quantity                                                                    1.0
#
#                                                                                    1  \
# Unnamed: 0                                                                         1
# projectid                                           ffff97ed93720407d70a2787475932b0
# donor_city                                                                       NaN
# donor_state                                                                       NY
# donation_to_project                                                            212.5
# donation_optional_support                                                       37.5
# donation_total                                                                 250.0
# donation_message                   I gave to this project because I am helping MC...
# teacher_acctid                                      462270f5d5c212162fcab11afa2623cb
# title                                   Kindergarten In Need of Important Materials!
# short_description                  It takes a special person to donate to a group...
# need_statement                     My students need 17 assorted classroom materia...
# essay                              Hi. I teach a wonderful group of 4-5 year old ...
# is_exciting                                                                        f
# at_least_1_teacher_referred_donor                                                  f
# fully_funded                                                                       t
# at_least_1_green_donation                                                          t
# great_chat                                                                         t
# school_city                                                                 Brooklyn
# school_state                                                                      NY
# school_zip                                                                   11234.0
# schoolid                                            9943fdb43ab5f2b53f27e961caf9e90a
# school_charter                                                                     f
# teacher_teach_for_america                                                          f
# primary_focus_subject                                              Early Development
# resource_type                                                               Supplies
# poverty_level                                                        highest poverty
# grade_level                                                            Grades PreK-2
# students_reached                                                                25.0
# date_posted                                                               2010-09-11
# vendorid                                                                       767.0
# project_resource_type                                                       Supplies
# item_number                                                                    VX748
# item_unit_price                                                                69.95
# item_quantity                                                                    1.0
#
#                                                                                    2  \
# Unnamed: 0                                                                         2
# projectid                                           ffff418bb42fad24347527ad96100f81
# donor_city                                                                       NaN
# donor_state                                                                       TX
# donation_to_project                                                             20.5
# donation_optional_support                                                        4.5
# donation_total                                                                  25.0
# donation_message                   I gave to this project because this school is ...
# teacher_acctid                                      e885fb002a1d0d39aaed9d21a7683549
# title                                                         Whistle While We Work!
# short_description                  By using the cross curricular games requested,...
# need_statement                     My students need grade level appropriate games...
# essay                              All work and no play makes school a dull place...
# is_exciting                                                                        f
# at_least_1_teacher_referred_donor                                                  f
# fully_funded                                                                       f
# at_least_1_green_donation                                                          t
# great_chat                                                                         t
# school_city                                                                   Austin
# school_state                                                                      TX
# school_zip                                                                   78730.0
# schoolid                                            6c6ea0558a03d113856e828ca7706092
# school_charter                                                                     f
# teacher_teach_for_america                                                          f
# primary_focus_subject                                           Literature & Writing
# resource_type                                                               Supplies
# poverty_level                                                            low poverty
# grade_level                                                               Grades 3-5
# students_reached                                                                20.0
# date_posted                                                               2009-04-03
# vendorid                                                                       773.0
# project_resource_type                                                       Supplies
# item_number                                                               1283493030
# item_unit_price                                                               694.98
# item_quantity                                                                    1.0
#
#                                                                                    3  \
# Unnamed: 0                                                                         3
# projectid                                           ffff2d9c769c8fb5335e949c615425eb
# donor_city                                                                       NaN
# donor_state                                                                       ID
# donation_to_project                                                            58.65
# donation_optional_support                                                      10.35
# donation_total                                                                  69.0
# donation_message                   Education is the most important thing in the w...
# teacher_acctid                                      485784e52a4c85ea6783285d09d8aea4
# title                                                          Too Close for Comfort
# short_description                  Have you ever had to crowd around an iPad scre...
# need_statement                     My students need another iPad to experience te...
# essay                              Have you ever had to crowd around an iPad scre...
# is_exciting                                                                        t
# at_least_1_teacher_referred_donor                                                  t
# fully_funded                                                                       t
# at_least_1_green_donation                                                          t
# great_chat                                                                         t
# school_city                                                                Pocatello
# school_state                                                                      ID
# school_zip                                                                   83204.0
# schoolid                                            f8e49225a821cc04e1176303e55d89ec
# school_charter                                                                     f
# teacher_teach_for_america                                                          f
# primary_focus_subject                                                    Mathematics
# resource_type                                                             Technology
# poverty_level                                                           high poverty
# grade_level                                                               Grades 3-5
# students_reached                                                                25.0
# date_posted                                                               2013-03-03
# vendorid                                                                        82.0
# project_resource_type                                                     Technology
# item_number                                                               BB12424888
# item_unit_price                                                               499.99
# item_quantity                                                                    1.0
#
#                                                                                    4
# Unnamed: 0                                                                         4
# projectid                                           fffeebf4827d745aa36b17c2d38d1966
# donor_city                                                                       NaN
# donor_state                                                                       CA
# donation_to_project                                                            797.3
# donation_optional_support                                                      140.7
# donation_total                                                                 938.0
# donation_message                   Chevron is committed to securing America's fut...
# teacher_acctid                                      96c1a33b4f2b832595c3c6a01bc24c05
# title                                                               Toot Your Flute!
# short_description                  The rewards of playing a musical instrument is...
# need_statement                     My students need access to a flute and percuss...
# essay                              The rewards of playing a musical instrument is...
# is_exciting                                                                        f
# at_least_1_teacher_referred_donor                                                  f
# fully_funded                                                                       t
# at_least_1_green_donation                                                          f
# great_chat                                                                         f
# school_city                                                                Fair Oaks
# school_state                                                                      CA
# school_zip                                                                   95628.0
# schoolid                                            7bb6b1924a7bd181ab5568b062260966
# school_charter                                                                     f
# teacher_teach_for_america                                                          f
# primary_focus_subject                                                          Music
# resource_type                                                                  Other
# poverty_level                                                        highest poverty
# grade_level                                                               Grades 6-8
# students_reached                                                                11.0
# date_posted                                                               2012-12-01
# vendorid                                                                       430.0
# project_resource_type                                                          Other
# item_number                                                                   400280
# item_unit_price                                                                59.99
# item_quantity                                                                    1.0

# %% [markdown]
# ## KEY OBSERVATIONS

# %% [raw]
# #Categorizing the types of features we have:
# Unstructured_data: donation_message, title, short_description, need_statement, essay
#
# One_hot_encode: donor_city, school_city, school_state,primary_focus_subject, resource_type, poverty_level, grade_level,  project_resource_type,teacher_acctid, item_number
#
# to_object: school_zip, vendorid
#
# to_drop(possibly): projectid, Unnamed: 0
#
# true/false columns to convert to (0 and 1): is_exciting,at_least_1_teacher_referred_donor,fully_funded,at_least_1_green_donation, great_chat
#
# to_feature_engineer: date_posted

# %% [raw]
# --Check the following features(likely to vary less or correlate)
# #donation_message used to calculate great_chat
# #check school_charter
# #primary_focus_subject
# #check resource_type and project_resource_type

# %%
#checking for the unique number of features in selected features.
print('Unique project ids:', df['projectid'].nunique())
print('Unique item_number ids:', df['item_number'].nunique())
print('Unique teacher_acctid ids:', df['teacher_acctid'].nunique())
print('Unique vendorid ids:', df['vendorid'].nunique())
print('Unique dates:', df['date_posted'].nunique())
print('Unique school ids:', df['schoolid'].nunique())
# Out:
# Unique project ids: 524949
# Unique item_number ids: 178340
# Unique teacher_acctid ids: 208169
# Unique vendorid ids: 327
# Unique dates: 3874
# Unique school ids: 51996

# %% [raw]
# #resource_type and project_resource_type are the same (drop one)
# #great_chat was derived from donation_message (drop one)
# #dropping the projectid column since it is unique for every column

# %%
#Checking for the data types
df.dtypes
# Out:
# Unnamed: 0                             int64
# projectid                             object
# donor_city                            object
# donor_state                           object
# donation_to_project                  float64
# donation_optional_support            float64
# donation_total                       float64
# donation_message                      object
# teacher_acctid                        object
# title                                 object
# short_description                     object
# need_statement                        object
# essay                                 object
# is_exciting                           object
# at_least_1_teacher_referred_donor     object
# fully_funded                          object
# at_least_1_green_donation             object
# great_chat                            object
# school_city                           object
# school_state                          object
# school_zip                           float64
# schoolid                              object
# school_charter                        object
# teacher_teach_for_america             object
# primary_focus_subject                 object
# resource_type                         object
# poverty_level                         object
# grade_level                           object
# students_reached                     float64
# date_posted                           object
# vendorid                             float64
# project_resource_type                 object
# item_number                           object
# item_unit_price                      float64
# item_quantity                        float64
# dtype: object

# %%
#Features to be used.
df.columns
# Out:
# Index(['Unnamed: 0', 'projectid', 'donor_city', 'donor_state',
#        'donation_to_project', 'donation_optional_support', 'donation_total',
#        'donation_message', 'teacher_acctid', 'title', 'short_description',
#        'need_statement', 'essay', 'is_exciting',
#        'at_least_1_teacher_referred_donor', 'fully_funded',
#        'at_least_1_green_donation', 'great_chat', 'school_city',
#        'school_state', 'school_zip', 'schoolid', 'school_charter',
#        'teacher_teach_for_america', 'primary_focus_subject', 'resource_type',
#        'poverty_level', 'grade_level', 'students_reached', 'date_posted',
#        'vendorid', 'project_resource_type', 'item_number', 'item_unit_price',
#        'item_quantity'],
#       dtype='object')

# %%
#Checking for the null values in the features
df.isna().sum()
# Out:
# Unnamed: 0                                0
# projectid                                 0
# donor_city                           270816
# donor_state                           90853
# donation_to_project                       0
# donation_optional_support                 0
# donation_total                            0
# donation_message                     156920
# teacher_acctid                            0
# title                                    17
# short_description                        67
# need_statement                          752
# essay                                     2
# is_exciting                               0
# at_least_1_teacher_referred_donor       357
# fully_funded                              0
# at_least_1_green_donation               357
# great_chat                                0
# school_city                               0
# school_state                              0
# school_zip                                4
# schoolid                                  0
# school_charter                            0
# teacher_teach_for_america                 0
# primary_focus_subject                    26
# resource_type                            33
# poverty_level                             0
# grade_level                               2
# students_reached                        115
# date_posted                               0
# vendorid                              25210
# project_resource_type                    33
# item_number                           10072
# item_unit_price                        6290
# item_quantity                          5562
# dtype: int64

# %% [raw]
# DROPPING COLUMNS

# %%
df = df.drop(['donation_message','project_resource_type','projectid'], axis = 1)

# %%
df = df.drop('Unnamed: 0', axis =1 )

# %% [raw]
# ASSIGNING THE RIGHT DATA TYPES TO COLUMNS

# %%
#school_zip, vendorid
df['school_zip'] = df['school_zip'].astype('str')
df['vendorid'] = df['vendorid'].astype('str')

# %% [raw]
# REPLACING NULL VALUES

# %%
df[["donor_city","donor_state","need_statement","title","short_description","essay"]] = df[["donor_city","donor_state","need_statement","title","short_description","essay"]].fillna("Not available")

# %%
#at_least_1_teacher_referred_donor,at_least_1_green_donation,school_zip,primary_focus_subject,resource_type,poverty_level,grade_level, item_number 
df[["at_least_1_teacher_referred_donor","at_least_1_green_donation","school_zip","primary_focus_subject","resource_type","poverty_level","grade_level","item_number"]] =df[["at_least_1_teacher_referred_donor","at_least_1_green_donation","school_zip","primary_focus_subject","resource_type","poverty_level","grade_level","item_number"]].fillna("Unknown")

# %%
#Numeric ones: students_reached,item_unit_price, item_quantity
df[["students_reached","item_unit_price","item_quantity"]].describe()
# Out:
#        students_reached  item_unit_price  item_quantity
# count     524834.000000    518659.000000  519387.000000
# mean          94.376685       140.560319       7.938653
# std         1666.877473       307.411905    1378.186089
# min            0.000000       -39.600000       0.000000
# 25%           22.000000        11.950000       1.000000
# 50%           30.000000        37.410000       1.000000
# 75%           99.000000       179.000000       3.000000
# max       999999.000000     93425.780000  993108.000000

# %%
#Observation: since the mean values varry significantly from the median, there are outliers affecting the mean"
#Replacing values with the median, which is less susceptible to outlier effect
import numpy as np
df[["students_reached","item_unit_price","item_quantity"]] = df[["students_reached","item_unit_price","item_quantity"]].fillna({
    "students_reached": df["students_reached"].median(),
    "item_unit_price": df["item_unit_price"].median(),
    "item_quantity": df["item_quantity"].median()})

# %%
df.isna().sum()
# Out:
# donor_city                           0
# donor_state                          0
# donation_to_project                  0
# donation_optional_support            0
# donation_total                       0
# teacher_acctid                       0
# title                                0
# short_description                    0
# need_statement                       0
# essay                                0
# is_exciting                          0
# at_least_1_teacher_referred_donor    0
# fully_funded                         0
# at_least_1_green_donation            0
# great_chat                           0
# school_city                          0
# school_state                         0
# school_zip                           0
# schoolid                             0
# school_charter                       0
# teacher_teach_for_america            0
# primary_focus_subject                0
# resource_type                        0
# poverty_level                        0
# grade_level                          0
# students_reached                     0
# date_posted                          0
# vendorid                             0
# item_number                          0
# item_unit_price                      0
# item_quantity                        0
# dtype: int64

# %%
df.dtypes
# Out:
# donor_city                            object
# donor_state                           object
# donation_to_project                  float64
# donation_optional_support            float64
# donation_total                       float64
# teacher_acctid                        object
# title                                 object
# short_description                     object
# need_statement                        object
# essay                                 object
# is_exciting                           object
# at_least_1_teacher_referred_donor     object
# fully_funded                          object
# at_least_1_green_donation             object
# great_chat                            object
# school_city                           object
# school_state                          object
# school_zip                            object
# schoolid                              object
# school_charter                        object
# teacher_teach_for_america             object
# primary_focus_subject                 object
# resource_type                         object
# poverty_level                         object
# grade_level                           object
# students_reached                     float64
# date_posted                           object
# vendorid                              object
# item_number                           object
# item_unit_price                      float64
# item_quantity                        float64
# dtype: object

# %%
#Converting date columns as string to datetime object
df['date_posted'] = pd.to_datetime(df['date_posted'])

# %%
#Selecting data from 2003 to 2012
df_2003_2012 = df[df['date_posted'].dt.year != 2013]

# %%
df_2003_2012['date_posted'].unique()
# Out:
# <DatetimeArray>
# ['2011-06-11 00:00:00', '2010-09-11 00:00:00', '2009-04-03 00:00:00',
#  '2012-12-01 00:00:00', '2010-11-15 00:00:00', '2006-11-22 00:00:00',
#  '2009-05-12 00:00:00', '2011-07-26 00:00:00', '2010-12-12 00:00:00',
#  '2012-01-14 00:00:00',
#  ...
#  '2003-01-12 00:00:00', '2002-12-17 00:00:00', '2007-06-27 00:00:00',
#  '2005-04-16 00:00:00', '2005-12-24 00:00:00', '2004-08-07 00:00:00',
#  '2006-03-04 00:00:00', '2002-11-06 00:00:00', '2003-07-01 00:00:00',
#  '2003-04-30 00:00:00']
# Length: 3509, dtype: datetime64[ns]

# %%
n = len(df_2003_2012)  # total number of rows
sample_size = 15000
step = n // sample_size  # calculate step size

# Systematic sampling
df1 = df_2003_2012.iloc[::step].head(sample_size)

# %%
df1.shape
# Out:
# (15000, 31)

# %% [raw]
# df1.to_csv('mlfile_2003_2012.csv')

# %% [markdown]
# ## FEATURE ENGINEER(DATE_COLUMN)

# %%
df1['school_zip'] = df1['school_zip'].astype('str')
df1['vendorid'] = df1['vendorid'].astype('str')

# %%
df1['year'] = df1['date_posted'].dt.year

# %%
df1['month'] = df1['date_posted'].dt.month

# %%
df1 = df1.drop('date_posted', axis = 1)

# %% [raw]
# ONE-HOT ENCODING

# %%
#Converting our target variable (fully_funded) to numerical values
df1['fully_funded'] = df1['fully_funded'].replace({'t':1, 'f':0}).astype('int')
# Out:
# C:\Users\davef\AppData\Local\Temp\ipykernel_209964\3565808953.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df1['fully_funded'] = df1['fully_funded'].replace({'t':1, 'f':0}).astype('int')

# %%
df1['fully_funded'].unique()
# Out:
# array([1, 0])

# %% [raw]
# for col in df1.columns:
#     print(f"{col}: {df1[col].unique()}")

# %%
df1.shape
# Out:
# (15000, 32)

# %%
for col in df1.columns:
    print(f'{col}: {df1[col].nunique()}')
# Out:
# donor_city: 2080
# donor_state: 58
# donation_to_project: 5228
# donation_optional_support: 4231
# donation_total: 5461
# teacher_acctid: 13142
# title: 14589
# short_description: 14963
# need_statement: 14844
# essay: 14997
# is_exciting: 2
# at_least_1_teacher_referred_donor: 3
# fully_funded: 2
# at_least_1_green_donation: 3
# great_chat: 2
# school_city: 2560
# school_state: 51
# school_zip: 4819
# schoolid: 9033
# school_charter: 2
# teacher_teach_for_america: 2
# primary_focus_subject: 27
# resource_type: 6
# poverty_level: 4
# grade_level: 4
# students_reached: 365
# vendorid: 97
# item_number: 11544
# item_unit_price: 3876
# item_quantity: 99
# year: 11
# month: 12

# %% [raw]
# FEATURE SELECTION

# %%
#Feature selection was done based on domain knowledge.
#Features of high importance but low cardinality were selected to accommodate for computing limitations.
df1 = df1[['is_exciting','donor_state','school_state','at_least_1_teacher_referred_donor','vendorid','great_chat','school_charter',
        'teacher_teach_for_america','primary_focus_subject','resource_type','poverty_level','grade_level','month','year','fully_funded']]

# %%
df1.dtypes
# Out:
# is_exciting                          object
# donor_state                          object
# school_state                         object
# at_least_1_teacher_referred_donor    object
# vendorid                             object
# great_chat                           object
# school_charter                       object
# teacher_teach_for_america            object
# primary_focus_subject                object
# resource_type                        object
# poverty_level                        object
# grade_level                          object
# month                                 int32
# year                                  int32
# fully_funded                          int32
# dtype: object

# %%
for col in df1.columns:
    print(f'{col}: {df1[col].nunique()}')
# Out:
# is_exciting: 2
# donor_state: 58
# school_state: 51
# at_least_1_teacher_referred_donor: 3
# vendorid: 97
# great_chat: 2
# school_charter: 2
# teacher_teach_for_america: 2
# primary_focus_subject: 27
# resource_type: 6
# poverty_level: 4
# grade_level: 4
# month: 12
# year: 11
# fully_funded: 2

# %%
X = df1.drop('fully_funded',axis = 1)
y = df1['fully_funded']

# %%
X.dtypes
# Out:
# is_exciting                          object
# donor_state                          object
# school_state                         object
# at_least_1_teacher_referred_donor    object
# vendorid                             object
# great_chat                           object
# school_charter                       object
# teacher_teach_for_america            object
# primary_focus_subject                object
# resource_type                        object
# poverty_level                        object
# grade_level                          object
# month                                 int32
# year                                  int32
# dtype: object

# %%
X.shape
# Out:
# (15000, 14)

# %%
#Building a preprocessing pipeline
from sklearn.pipeline import  Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer

ohe_cols = X.select_dtypes(['object']).columns
num_cols = X.select_dtypes(['float64','int64']).columns



preprocessor = ColumnTransformer(
    transformers=[
        ('ohe', Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='constant', fill_value='unknown')),
            ('onehot', OneHotEncoder(handle_unknown='ignore',sparse_output = False))
        ]), ohe_cols),
        
        ('num', Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='median')),
            ('scaler', StandardScaler())
        ]), num_cols)
    ],
    remainder='passthrough'
)

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 2025, stratify = y)

# %%
from sklearn.pipeline import  Pipeline
from sklearn.metrics import f1_score
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline

# %% [markdown]
# ## Classification with SGDClassifier Using Logisitc Regression

# %%
from sklearn.linear_model import SGDClassifier 
from sklearn.model_selection import cross_val_score, StratifiedKFold
pipe = ImbPipeline([
    ('preprocessor',preprocessor),
    ('smote',SMOTE(sampling_strategy = 'minority', random_state=2025)),
    ('clf', SGDClassifier())
])
# Parameter grid
model_params = {
    'clf__alpha': [0.001, 0.01, 0.1, 1],
    'clf__max_iter': [4000, 8000],
    'clf__loss': ['log_loss'],
    'clf__penalty': ['l2'],
    'clf__tol': [1e-3],
    'clf__random_state': [42]
}



cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=2025)
# Grid search
model = GridSearchCV(pipe, model_params, cv=cv, scoring='f1')

# %%
model.fit(X_train, y_train)
# Out:
# C:\anaconda\Lib\site-packages\sklearn\compose\_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=2025, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ohe',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(fill_value='unknown',
#                                                                                                         strategy='constant')),
#                                                                                          ('onehot',
#                                                                                           OneHotEncoder(handle_unknown='ignore',
#                                                                                                         sparse_output=False))]),
#                                                                          Index(['is_exc...
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          Index([], dtype='object'))])),
#                                        ('smote',
#                                         SMOTE(random_state=2025,
#                                               sampling_strategy='minority')),
#                                        ('clf', SGDClassifier())]),
#              param_grid={'clf__alpha': [0.001, 0.01, 0.1, 1],
#                          'clf__loss': ['log_loss'],
#                          'clf__max_iter': [4000, 8000], 'clf__penalty': ['l2'],
#                          'clf__random_state': [42], 'clf__tol': [0.001]},
#              scoring='f1')

# %%
print("Test Model F1 Score:", model.score(X_test, y_test))

print("Train Model F1 Score:", model.score(X_train, y_train))
# Out:
# Test Model F1 Score: 0.9025059447594659
# Train Model F1 Score: 0.9025059447594659

# %%
from sklearn.metrics import f1_score, classification_report, confusion_matrix

y_predicted= model.predict(X_test)

cm = confusion_matrix(y_test,y_predicted)
print(cm)
# Out:
# [[   0  533]
#  [   0 2467]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (8,5))
sns.heatmap(cm, annot= True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.title('Classification Using SGDClassifier with Logistic Regression')
# Out:
# Text(0.5, 1.0, 'Classification Using SGDClassifier with Logistic Regression')

# %% [markdown]
# ## Classification Using RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier
pipe2 = ImbPipeline([
    ('preprocessor',preprocessor),
    ('smote',SMOTE(sampling_strategy = 'minority', random_state=2025)),
    ('clf', RandomForestClassifier())
])

# Parameter grid
model_params = {
    'clf__n_estimators': [10,20,30,40,50]
}


cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=2025)
model = GridSearchCV(pipe2, model_params, cv=cv, scoring='f1')

# %%
model.fit(X_train, y_train)
# Out:
# C:\anaconda\Lib\site-packages\sklearn\compose\_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=2025, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ohe',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(fill_value='unknown',
#                                                                                                         strategy='constant')),
#                                                                                          ('onehot',
#                                                                                           OneHotEncoder(handle_unknown='ignore',
#                                                                                                         sparse_output=False))]),
#                                                                          Index(['is_exc...
#        'resource_type', 'poverty_level', 'grade_level'],
#       dtype='object')),
#                                                                         ('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          Index([], dtype='object'))])),
#                                        ('smote',
#                                         SMOTE(random_state=2025,
#                                               sampling_strategy='minority')),
#                                        ('clf', RandomForestClassifier())]),
#              param_grid={'clf__n_estimators': [10, 20, 30, 40, 50]},
#              scoring='f1')

# %%
print("Test Model F1 Score:", model.score(X_test, y_test))

print("Train Model F1 Score:", model.score(X_train, y_train))
# Out:
# Test Model F1 Score: 0.8923894477130385
# Train Model F1 Score: 0.9994428405004305

# %%
from sklearn.metrics import f1_score, classification_report, confusion_matrix

y_predicted= model.predict(X_test)

cm = confusion_matrix(y_test,y_predicted)
print(cm)
# Out:
# [[  82  451]
#  [ 116 2351]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (8,5))
sns.heatmap(cm, annot= True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.title('Classification Using Random Forest')
# Out:
# Text(0.5, 1.0, 'Classification Using Random Forest')

# %% [markdown]
# ## CLASSIFYING WITH GRADIENT BOOSTING

# %%
from xgboost import XGBClassifier

pipe3 = ImbPipeline([
    ('preprocessor',preprocessor),
    ('smote',SMOTE(sampling_strategy = 'minority', random_state=2025)),
    ('clf', XGBClassifier())
])

# Parameter grid
model_params = {
    'clf__n_estimators': [10,20,30,40,50]
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=2025)
model = GridSearchCV(pipe3, model_params, cv=cv, scoring='f1')

# %%
model.fit(X_train, y_train)
# Out:
# C:\anaconda\Lib\site-packages\sklearn\compose\_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=2025, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ohe',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(fill_value='unknown',
#                                                                                                         strategy='constant')),
#                                                                                          ('onehot',
#                                                                                           OneHotEncoder(handle_unknown='ignore',
#                                                                                                         sparse_output=False))]),
#                                                                          Index(['is_exc...
#                                                       interaction_constraints=None,
#                                                       learning_rate=None,
#                                                       max_bin=None,
#                                                       max_cat_threshold=None,
#                                                       max_cat_to_onehot=None,
#                                                       max_delta_step=None,
#                                                       max_depth=None,
#                                                       max_leaves=None,
#                                                       min_child_weight=None,
#                                                       missing=nan,
#                                                       monotone_constraints=None,
#                                                       multi_strategy=None,
#                                                       n_estimators=None,
#                                                       n_jobs=None,
#                                                       num_parallel_tree=None, ...))]),
#              param_grid={'clf__n_estimators': [10, 20, 30, 40, 50]},
#              scoring='f1')

# %%
print("Test Model F1 Score:", model.score(X_test, y_test))

print("Train Model F1 Score:", model.score(X_train, y_train))
# Out:
# Test Model F1 Score: 0.9005825972561549
# Train Model F1 Score: 0.9143396226415095

# %%
from sklearn.metrics import f1_score, classification_report, confusion_matrix

y_predicted= model.predict(X_test)

cm = confusion_matrix(y_test,y_predicted)
print(cm)
# Out:
# [[  75  458]
#  [  71 2396]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (8,5))
sns.heatmap(cm, annot= True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.title('Classification Using XGBClassifier')
# Out:
# Text(0.5, 1.0, 'Classification Using XGBClassifier')

# %%
#Exporting the model
import pickle

with open('model_pickle','wb') as f:
    pickle.dump(model,f)

# %% [markdown]
# ## FINDING PROJECTS LESS LIKELY TO BE FUNDED IN 2013

# %%
df_2013 = df[df['date_posted'].dt.year == 2013]

# %%
df_2013.shape
# Out:
# (114998, 31)

# %% [raw]
# df_2013.to_csv('df_2012_2013.csv')

# %%
df2 = df_2013

# %%
df2['school_zip'] = df2['school_zip'].astype('str')
df2['vendorid'] = df2['vendorid'].astype('str')

df2['year'] = df2['date_posted'].dt.year
df2['month'] = df2['date_posted'].dt.month

df2 = df2.drop('date_posted', axis = 1)
df2['fully_funded'] = df2['fully_funded'].replace({'t':1, 'f':0}).astype('int')

#to add: 'donor_state','school_state','vendorid'
df2 = df2[['is_exciting','donor_state','school_state','at_least_1_teacher_referred_donor','vendorid','great_chat','school_charter',
        'teacher_teach_for_america','primary_focus_subject','resource_type','poverty_level','grade_level','month','year','fully_funded']]

X = df2.drop('fully_funded',axis = 1)
y = df2['fully_funded']
# Out:
# C:\Users\davef\AppData\Local\Temp\ipykernel_209964\1117451204.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['school_zip'] = df2['school_zip'].astype('str')
# C:\Users\davef\AppData\Local\Temp\ipykernel_209964\1117451204.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['vendorid'] = df2['vendorid'].astype('str')
# C:\Users\davef\AppData\Local\Temp\ipykernel_209964\1117451204.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['year'] = df2['date_posted'].dt.year
# C:\Users\davef\AppData\Local\Temp\ipykernel_209964\1117451204.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['month'] = df2['date_posted'].dt.month
# C:\Users\davef\AppData\Local\Temp\ipykernel_209964\1117451204.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2['fully_funded'] = df2['fully_funded'].replace({'t':1, 'f':0}).astype('int')

# %%
import pickle
with open('model_pickle','rb') as f:
    model = pickle.load(f)

# %%
prob_class_0 = model.predict_proba(X)[:,0]

# %%
y_pred = model.best_estimator_.predict(X)
print(confusion_matrix(y, y_pred))
# Out:
# [[ 5047 17577]
#  [ 4240 88134]]

# %%
from sklearn.metrics import classification_report
y_pred = model.best_estimator_.predict(X)
print(classification_report(y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.22      0.32     22624
#            1       0.83      0.95      0.89     92374
#
#     accuracy                           0.81    114998
#    macro avg       0.69      0.59      0.60    114998
# weighted avg       0.78      0.81      0.78    114998

# %%
#find the bottom 10% of projects less_likely to be funded
prob_class_0[:10]
# Out:
# array([0.00502777, 0.23024786, 0.06381261, 0.6328957 , 0.27275175,
#        0.43442374, 0.15398139, 0.2795804 , 0.00384432, 0.36544132],
#       dtype=float32)

# %%
prob_class_0.shape
# Out:
# (114998,)

# %%
X_with_probs = X.copy()
X_with_probs['prob_class_0'] = prob_class_0

# %%
X_with_probs.shape
# Out:
# (114998, 15)

# %%
X_with_probs['fully_funded'] = y.values

# %%
less_likely_funded = X_with_probs[X_with_probs['fully_funded'] == 0]

# %%
bottom_10_percent = less_likely_funded.nsmallest(int(0.10*len(less_likely_funded)),'prob_class_0')

# %% [markdown]
# ## Projects less likely to be funded (bottom 10%)

# %%
bottom_10_percent.head(10)
# Out:
#        is_exciting donor_state school_state at_least_1_teacher_referred_donor  \
# 352175           f          CA           TX                                 t
# 254937           f          CA           CA                                 f
# 207445           f          CA           NV                                 t
# 326567           f          CA           HI                                 f
# 9110             f          CA           IL                                 t
# 212495           f          MI           IL                                 t
# 371096           f          CA           MO                                 t
# 241953           f          NY           MI                                 t
# 493049           f          NY           MI                                 t
# 304705           f          CA           TX                                 t
#
#        vendorid great_chat school_charter teacher_teach_for_america  \
# 352175     27.0          f              f                         f
# 254937    194.0          f              t                         f
# 207445    773.0          f              f                         f
# 326567    767.0          f              f                         f
# 9110      767.0          f              f                         f
# 212495     47.0          f              f                         f
# 371096    430.0          f              f                         f
# 241953    767.0          f              t                         f
# 493049    754.0          f              f                         f
# 304705    757.0          f              f                         f
#
#         primary_focus_subject resource_type    poverty_level    grade_level  \
# 352175  Environmental Science         Books  highest poverty     Grades 3-5
# 254937  Environmental Science         Books  highest poverty     Grades 3-5
# 207445            Mathematics      Supplies  highest poverty     Grades 3-5
# 326567            Mathematics      Supplies  highest poverty  Grades PreK-2
# 9110              Mathematics      Supplies  highest poverty     Grades 3-5
# 212495  Environmental Science         Books  highest poverty     Grades 6-8
# 371096                  Music      Supplies  highest poverty     Grades 3-5
# 241953            Visual Arts      Supplies  highest poverty  Grades PreK-2
# 493049                 Sports      Supplies  highest poverty     Grades 3-5
# 304705   Literature & Writing      Supplies  highest poverty     Grades 3-5
#
#         month  year  prob_class_0  fully_funded
# 352175     12  2013      0.015851             0
# 254937      9  2013      0.018861             0
# 207445     12  2013      0.022180             0
# 326567     12  2013      0.023769             0
# 9110       11  2013      0.025332             0
# 212495     11  2013      0.026643             0
# 371096     12  2013      0.028625             0
# 241953     11  2013      0.029614             0
# 493049      3  2013      0.030237             0
# 304705     12  2013      0.030267             0

# %%
bottom_10_percent.shape
# Out:
# (2262, 16)

# %% [markdown]
# ## ANALYSIS ON BOTTOM 10%

# %%
##Checking for the porportion of unfunded projects based on the poverty level
city_fund = pd.crosstab(bottom_10_percent['poverty_level'],bottom_10_percent['fully_funded'])

plt.figure(figsize=(10,5))
city_fund.plot(kind = 'bar')
plt.xlabel('Poverty_level')
plt.ylabel('Count')
plt.title('Count of funding by poverty_level')
plt.tight_layout()

# %%
#Checking for the porportion of unfunded projects based on the types of resources requested
city_fund = pd.crosstab(bottom_10_percent['resource_type'],bottom_10_percent['fully_funded'])

plt.figure(figsize=(10,5))
city_fund.plot(kind = 'bar')
plt.xlabel('Resource type')
plt.ylabel('Count')
plt.title('Count of funding by resource type')
plt.tight_layout()

# %%
#Checking for the porportion of unfunded projects using school's states
city_fund = pd.crosstab(bottom_10_percent['school_state'],bottom_10_percent['fully_funded'])

plt.figure(figsize=(14,5))
city_fund.plot(kind = 'bar')
plt.xlabel('States')
plt.ylabel('Count')
plt.title('Count of funding by states')
plt.tight_layout()

# %%
##Checking for the porportion of unfunded projects based on great or bad chats
city_fund = pd.crosstab(bottom_10_percent['great_chat'],bottom_10_percent['fully_funded'])

plt.figure(figsize=(14,5))
city_fund.plot(kind = 'bar')
plt.xlabel('States')
plt.ylabel('Count')
plt.title('Count of funding by great_chat')
plt.tight_layout()

# %%
##Checking for the porportion of unfunded projects based on the primary_focus_subject
city_fund = pd.crosstab(bottom_10_percent['primary_focus_subject'],bottom_10_percent['fully_funded'])

plt.figure(figsize=(14,5))
city_fund.plot(kind = 'bar')
plt.xlabel('States')
plt.ylabel('Count')
plt.title('Count of funding by primary focus subject')
plt.tight_layout()

# %%
##Checking for the porportion of unfunded projects using grade level
city_fund = pd.crosstab(bottom_10_percent['grade_level'],bottom_10_percent['fully_funded'])

plt.figure(figsize=(14,5))
city_fund.plot(kind = 'bar')
plt.xlabel('States')
plt.ylabel('Count')
plt.title('Count of funding by grade level')
plt.tight_layout()

# %%
##Checking for the porportion of unfunded projects based on the status of the teacher(American or not)
city_fund = pd.crosstab(bottom_10_percent['teacher_teach_for_america'],bottom_10_percent['fully_funded'])

plt.figure(figsize=(14,5))
city_fund.plot(kind = 'bar')
plt.xlabel('States')
plt.ylabel('Count')
plt.title('Count of funding by if tutor involved teaches for America')
plt.tight_layout()
